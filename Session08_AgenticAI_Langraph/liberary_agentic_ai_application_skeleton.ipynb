# %%
from langgraph.graph import StateGraph , START , END

# %%
from typing import TypedDict, Optional

class liberary_state(TypedDict):
    question: Optional[str]
    faq_answer: Optional[str]
    checkout_info: Optional[str]
    final_answer: Optional[str]


def classifier_agent(state: liberary_state):
    print("classifierAgent ran")
    print(f"state: {state}")
    return state

def faq_agent(state: liberary_state):
    print("faq agent ran")
    print(f"state: {state}")
    return state

def checkout_agent(state: )
