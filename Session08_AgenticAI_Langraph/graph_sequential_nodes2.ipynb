# %%
# python -m venv .venv
# source .venv/bin/activate  # On Windows, use `.venv\Scripts\activate`
# %pip install langgraph

# %% [markdown]
# ### Build a simple sequential graph using Langgraph

# %%
from langgraph.graph import StateGraph, START, END

# %%
def node_a_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent A is running")
    return {}

def node_b_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent B is running")
    return {}

builder = StateGraph(dict)

name_agent_a = "ImageRecognitionAgent"
name_agent_b = "RecommendationAgent"
builder.add_node(name_agent_a, node_a_agent)
builder.add_node(name_agent_b, node_b_agent)

builder.add_edge(START, name_agent_a)
builder.add_edge(name_agent_a, name_agent_b)
builder.add_edge(name_agent_b, END)


graph = builder.compile()

# %%
# %pip install grandalf
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- Display as ASCII ---
print(graph.get_graph().draw_ascii())
# Out:
#       +-----------+
#       | __start__ |
#       +-----------+
#             *
#             *
#             *
# +-----------------------+
# | ImageRecognitionAgent |
# +-----------------------+
#             *
#             *
#             *
#  +---------------------+
#  | RecommendationAgent |
#  +---------------------+
#             *
#             *
#             *
#        +---------+
#        | __end__ |
#        +---------+

# %%
# Invoke the graph with an empty initial state
initial_state = {}
graph.invoke(initial_state)
# Out:
# Agent A is running
# Agent B is running
# {}
