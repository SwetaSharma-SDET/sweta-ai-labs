# %%
# %pip install langchain langsmith openai python-dotenv
# %pip install langsmith
# %pip install langsmith==0.4.55

# %%
import langsmith, langchain
print(langsmith.__version__) #Alok - 0.4.59, Sundar - 0.4.55
print(langchain.__version__)
# Out:
# 0.3.45
# 0.3.25

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# --- Setup ---
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

print("API Key:", os.getenv("LANGCHAIN_API_KEY")[:2])
print("Project:", os.getenv("LANGCHAIN_PROJECT"))
print("Tracing:", os.getenv("LANGCHAIN_TRACING_V2"))
# Out:
# API Key: ls
# Project: Langsmith_Eval_June_2026
# Tracing: true

# %%
# Initialize model
client = OpenAI(api_key=my_api_key)

from langsmith import traceable # Need to enable tracing on LangSmith

# --- Function under test ---
@traceable # Enable tracing for this function on LangSmith - Only one line change
def ask_question(prompt) -> str:
    print(f"User asked: {prompt}")
    response = client.chat.completions.create(
        model="gpt-4.1-nano",
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."},
            {"role": "user", "content": prompt}
        ]
    )
    print (response)
    return response.choices[0].message.content

# %%
ask_question("where is the weather in mumbai?")
# Out:
# User asked: where is the weather in mumbai?
# ChatCompletion(id='chatcmpl-Dry1S7fWx6V0osDdAo7UNukSKM23E', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I cannot provide real-time weather updates. Please check a weather website or app for the current conditions in Mumbai.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1781754482, model='gpt-4.1-nano-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_0f961d15a9', usage=CompletionUsage(completion_tokens=22, prompt_tokens=33, total_tokens=55, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# 'I cannot provide real-time weather updates. Please check a weather website or app for the current conditions in Mumbai.'
