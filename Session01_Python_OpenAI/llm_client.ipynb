# %%
# %pip install python-dotenv
# %pip install openai
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [openai]15/16 [openai]c]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
my_api_key = os.getenv("OPENAI_API_KEY")
print(my_api_key[-5:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import os
#       2 from dotenv import load_dotenv
#       3 my_api_key = os.getenv("OPENAI_API_KEY")
# ----> 4 print(my_api_key[-5:])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# !pwd
# Out:
# /Users/suneelsharma/Documents/sweta/sweta-ai-labs/Session01_Python_OpenAI
