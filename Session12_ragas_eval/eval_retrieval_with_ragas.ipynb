# %%
#%pip install ragas

# %%
# %pip uninstall langchain langchain-community langchain-core -y

# %pip install \
langchain==0.3.25 \
langchain-community==0.3.24 \
langchain-core==0.3.66
# Out:
# Found existing installation: langchain 0.3.25
# Uninstalling langchain-0.3.25:
#   Successfully uninstalled langchain-0.3.25
# Found existing installation: langchain-community 0.3.24
# Uninstalling langchain-community-0.3.24:
#   Successfully uninstalled langchain-community-0.3.24
# Found existing installation: langchain-core 0.3.86
# Uninstalling langchain-core-0.3.86:
#   Successfully uninstalled langchain-core-0.3.86
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain==0.3.25
#   Using cached langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-community==0.3.24
#   Using cached langchain_community-0.3.24-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-core==0.3.66
#   Using cached langchain_core-0.3.66-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (0.3.45)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (2.13.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (2.0.50)
# Requirement already satisfied: requests<3,>=2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (2.34.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain==0.3.25) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core==0.3.66) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core==0.3.66) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core==0.3.66) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core==0.3.66) (4.15.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community==0.3.24) (3.14.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community==0.3.24) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community==0.3.24) (2.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community==0.3.24) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community==0.3.24) (2.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.24) (1.24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.24) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.24) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.66) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25) (0.23.0)
# Requirement already satisfied: anyio in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.25) (4.13.0)
# Requirement already satisfied: certifi in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.25) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.25) (1.0.9)
# Requirement already satisfied: idna in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.25) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.25) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.25) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.25) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.25) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.24) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests<3,>=2->langchain==0.3.25) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests<3,>=2->langchain==0.3.25) (2.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.24) (1.1.0)
# Using cached langchain-0.3.25-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.66-py3-none-any.whl (438 kB)
# Using cached langchain_community-0.3.24-py3-none-any.whl (2.5 MB)
# Installing collected packages: langchain-core, langchain, langchain-community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-community]ngchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.35 requires langchain-core<1.0.0,>=0.3.78, but you have langchain-core 0.3.66 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.66 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.66 which is incompatible.
# langgraph 1.2.4 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.66 which is incompatible.
# langchain-classic 1.0.8 requires langchain-core<2.0.0,>=1.4.4, but you have langchain-core 0.3.66 which is incompatible.
# langchain-classic 1.0.8 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.3.8 which is incompatible.
# Successfully installed langchain-0.3.25 langchain-community-0.3.24 langchain-core-0.3.66
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
reference_data = [
  {
    "question": "What’s the leave policy?", #Office condos for sale in 94539
    "ground_truth": "employees must submit a leave request for approval.", #Expected llm context
    #"context": "Employees must submit a leave request for approval. " #Expected context from source documents based on the question #2 properties
  }
]
question = reference_data[0]['question']
ground_truth = reference_data[0]['ground_truth']
context = ground_truth #reference_data[0]['context']
print (f"question: {question}")
print (f"ground_truth: {ground_truth}")
print (f"context: {context}")
# Out:
# question: What’s the leave policy?
# ground_truth: employees must submit a leave request for approval.
# context: employees must submit a leave request for approval.

# %%
# Retrieve context from Milvus DB
from milvus_chatbot_with_rag import retrieve_similiar_contexts

def perform_retrieval(question):

    retrieved_context = retrieve_similiar_contexts(question, "policy_docs_collection", 1)[0]['content']
    print (f"perform_retrieval.retrieved_context: {retrieved_context}")
    return retrieved_context

    
# retrieved_context = perform_retrieval("What’s the leave policy?")
retrieved_context = perform_retrieval(question)
# Out:
# /Users/suneelsharma/Documents/sweta/sweta-ai-labs/Session12_ragas_eval/milvus_chatbot_with_rag.py:28: PyMilvusDeprecationWarning: `connections.connect` is an ORM-style PyMilvus API and will be removed in PyMilvus 3.1. Use `MilvusClient` instead.
#   connections.connect(
# Connected to Milvus on Zilliz Cloud
# /Users/suneelsharma/Documents/sweta/sweta-ai-labs/Session12_ragas_eval/milvus_chatbot_with_rag.py:36: PyMilvusDeprecationWarning: `Collection` is an ORM-style PyMilvus API and will be removed in PyMilvus 3.1. Use `MilvusClient` instead.
#   collection = Collection(collection_name)
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6038.93it/s]
# /Users/suneelsharma/Documents/sweta/sweta-ai-labs/Session12_ragas_eval/milvus_chatbot_with_rag.py:41: PyMilvusDeprecationWarning: `Collection.search` is an ORM-style PyMilvus API and will be removed in PyMilvus 3.1. Use `MilvusClient` instead.
#   results = collection.search(
# perform_retrieval.retrieved_context: Employees must submit a leave request for approval.

# %%
# Validate retrieved context against reference data    

print(f"Retrieved context: {retrieved_context}")
print(f"Expected context: {context}")
print(f"question: {question}")
# Out:
# Retrieved context: Employees must submit a leave request for approval.
# Expected context: employees must submit a leave request for approval.
# question: What’s the leave policy?

# %%
# %pip install datasets 
# %pip install -u ragas
# %pip install ragas
# Out:
# I0617 18:38:55.769456 4116633 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(92, generation: 1)
# Requirement already satisfied: datasets in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (5.0.0)
# Requirement already satisfied: filelock in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: numpy>=1.17 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (2.4.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2026.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (1.15.0)
# Requirement already satisfied: packaging in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: click>=8.2.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (14.3.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# I0617 18:38:56.617434 4116668 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(92, generation: 1)
# [optparse.groups]Usage:[/]
#   /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/bin/python -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/bin/python -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/bin/python -m pip install \[options] [-e] <vcs project url> ...
#   /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/bin/python -m pip install \[options] [-e] <local project path> ...
#   /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/bin/python -m pip install \[options] <archive url/path> ...
#
# no such option: -u
# Note: you may need to restart the kernel to use updated packages.
# I0617 18:38:57.125139 4116711 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(92, generation: 1)
# Requirement already satisfied: ragas in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (0.4.3)
# Requirement already satisfied: numpy<3.0.0,>=1.21.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (2.4.5)
# Requirement already satisfied: datasets>=4.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (5.0.0)
# Requirement already satisfied: tiktoken in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.13.0)
# Requirement already satisfied: pydantic>=2.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (2.13.3)
# Requirement already satisfied: nest-asyncio in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (1.4.4)
# Requirement already satisfied: diskcache>=5.6.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (5.6.3)
# Requirement already satisfied: typer in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.25.1)
# Requirement already satisfied: rich in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (14.3.4)
# Requirement already satisfied: openai>=1.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (2.33.0)
# Requirement already satisfied: tqdm in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (4.67.3)
# Requirement already satisfied: instructor in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (1.15.3)
# Requirement already satisfied: pillow>=10.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (12.2.0)
# Requirement already satisfied: networkx in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (3.6.1)
# Requirement already satisfied: scikit-network in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.33.5)
# Requirement already satisfied: langchain in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.3.25)
# Requirement already satisfied: langchain-core in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.3.66)
# Requirement already satisfied: langchain-community in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.3.24)
# Requirement already satisfied: langchain_openai in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from ragas) (0.3.35)
# Requirement already satisfied: filelock in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (0.4.1)
# Requirement already satisfied: pandas in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (0.28.1)
# Requirement already satisfied: xxhash in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (2026.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (1.15.0)
# Requirement already satisfied: packaging in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from datasets>=4.0.0->ragas) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (3.14.1)
# Requirement already satisfied: anyio in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets>=4.0.0->ragas) (4.13.0)
# Requirement already satisfied: certifi in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets>=4.0.0->ragas) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets>=4.0.0->ragas) (1.0.9)
# Requirement already satisfied: idna in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets>=4.0.0->ragas) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.0.0->ragas) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.0.0->ragas) (1.24.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from openai>=1.0.0->ragas) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from openai>=1.0.0->ragas) (0.14.0)
# Requirement already satisfied: sniffio in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from openai>=1.0.0->ragas) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests>=2.32.2->datasets>=4.0.0->ragas) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from requests>=2.32.2->datasets>=4.0.0->ragas) (2.7.0)
# Requirement already satisfied: click>=8.2.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer->ragas) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer->ragas) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typer->ragas) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from rich->ragas) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from rich->ragas) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich->ragas) (0.1.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from instructor->ragas) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from instructor->ragas) (3.1.6)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from instructor->ragas) (9.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from jinja2<4.0.0,>=3.1.4->instructor->ragas) (3.0.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain->ragas) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain->ragas) (0.3.45)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain->ragas) (2.0.50)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (0.23.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community->ragas) (2.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-community->ragas) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas) (1.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.1.0)
# Collecting langchain-core (from ragas)
#   Using cached langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from langchain-core->ragas) (0.16.0)
# Requirement already satisfied: regex in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from tiktoken->ragas) (2026.5.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from pandas->datasets>=4.0.0->ragas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.0.0->ragas) (1.17.0)
# Requirement already satisfied: scipy>=1.7.3 in /Users/suneelsharma/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages (from scikit-network->ragas) (1.17.1)
# Using cached langchain_core-0.3.86-py3-none-any.whl (461 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.66
#     Uninstalling langchain-core-0.3.66:
#       Successfully uninstalled langchain-core-0.3.66
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph 1.2.4 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langchain-classic 1.0.8 requires langchain-core<2.0.0,>=1.4.4, but you have langchain-core 0.3.86 which is incompatible.
# langchain-classic 1.0.8 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.3.8 which is incompatible.
# Successfully installed langchain-core-0.3.86
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import context_precision, context_recall

from dotenv import load_dotenv
from openai import OpenAI
import os

# --- Load API Key ---
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")


client = OpenAI(api_key=my_api_key)

# question = reference_data[0]['question']
# ground_truth = reference_data[0]['ground_truth']
# context = reference_data[0]['context']
# Question User asked
question = reference_data[0]['question']

# Reference context (should be a string)
reference_context = reference_data[0]['ground_truth']

# Retrieved context (a string from perform_retrieval)
retrieved_context = [perform_retrieval(question)]

# Build dataset properly
dataset_dict = {
    "question": [question],
    "contexts": [retrieved_context],      # list of strings INSIDE another list
    "ground_truth": [reference_context],   # single string
    "answer": [""]
}

print(f"dataset_dict: {dataset_dict}")

ragas_dataset = Dataset.from_dict(dataset_dict)


# Evaluate retrieval
results = evaluate(
    dataset=ragas_dataset,
    metrics=[context_precision, context_recall]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 from datasets import Dataset
# ----> 2 from ragas import evaluate
#       3 from ragas.metrics import context_precision, context_recall
#       4
#       5 from dotenv import load_dotenv
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/ragas/__init__.py:5
#       3 from ragas.dataset import Dataset, DataTable
#       4 from ragas.dataset_schema import EvaluationDataset, MultiTurnSample, SingleTurnSample
# ----> 5 from ragas.evaluation import aevaluate, evaluate
#       6 from ragas.experiment import Experiment, experiment, version_experiment
#       7 from ragas.run_config import RunConfig
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/ragas/evaluation.py:21
#      14 from ragas.callbacks import ChainType, RagasTracer, new_group
#      15 from ragas.dataset_schema import (
#      16     EvaluationDataset,
#      17     EvaluationResult,
#      18     MultiTurnSample,
#      19     SingleTurnSample,
#      20 )
# ---> 21 from ragas.embeddings.base import (
#      22     BaseRagasEmbedding,
#      23     BaseRagasEmbeddings,
#      24     LangchainEmbeddingsWrapper,
#      25     _infer_embedding_provider_from_llm,
#      26     embedding_factory,
#      27 )
#      28 from ragas.exceptions import ExceptionInRunner
#      29 from ragas.executor import Executor
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/ragas/embeddings/__init__.py:3
#       1 # Legacy embeddings - maintain backward compatibility
#       2 # Modern embeddings - new interface
# ----> 3 from ragas.embeddings.base import (
#       4     BaseRagasEmbedding,
#       5     BaseRagasEmbeddings,
#       6     HuggingfaceEmbeddings,
#       7     LangchainEmbeddingsWrapper as _LangchainEmbeddingsWrapper,
#       8     LlamaIndexEmbeddingsWrapper as _LlamaIndexEmbeddingsWrapper,
#       9     embedding_factory as _embedding_factory,
#      10 )
#      11 from ragas.embeddings.google_provider import GoogleEmbeddings
#      12 from ragas.embeddings.haystack_wrapper import HaystackEmbeddingsWrapper
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/ragas/embeddings/base.py:12
#      10 import numpy as np
#      11 from langchain_core.embeddings import Embeddings
# ---> 12 from langchain_openai.embeddings import OpenAIEmbeddings
#      13 from pydantic.dataclasses import dataclass
#      14 from pydantic_core import CoreSchema, core_schema
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_openai/__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/azure.py:20
#      17 from pydantic import BaseModel, Field, SecretStr, model_validator
#      18 from typing_extensions import Literal, Self
# ---> 20 from langchain_openai.chat_models.base import BaseChatOpenAI
#      22 logger = logging.getLogger(__name__)
#      25 _BM = TypeVar("_BM", bound=BaseModel)
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:73
#      67 from langchain_core.messages.ai import (
#      68     InputTokenDetails,
#      69     OutputTokenDetails,
#      70     UsageMetadata,
#      71 )
#      72 from langchain_core.messages.tool import tool_call_chunk
# ---> 73 from langchain_core.output_parsers import JsonOutputParser, PydanticOutputParser
#      74 from langchain_core.output_parsers.openai_tools import (
#      75     JsonOutputKeyToolsParser,
#      76     PydanticToolsParser,
#      77     make_invalid_tool_call,
#      78     parse_tool_call,
#      79 )
#      80 from langchain_core.outputs import ChatGeneration, ChatGenerationChunk, ChatResult
#
# File <frozen importlib._bootstrap>:1431, in _handle_fromlist(module, fromlist, import_, recursive)
#    1428     if not recursive and hasattr(module, '__all__'):
#    1429         _handle_fromlist(module, module.__all__, import_,
#    1430                          recursive=True)
# -> 1431 elif not hasattr(module, x):
#    1432     from_name = f'{module.__name__}.{x}'
#    1433     try:
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_core/output_parsers/__init__.py:92, in __getattr__(attr_name)
#      90 def __getattr__(attr_name: str) -> object:
#      91     module_name = _dynamic_imports.get(attr_name)
# ---> 92     result = import_attr(attr_name, module_name, __spec__.parent)
#      93     globals()[attr_name] = result
#      94     return result
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_core/_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      10 """Import an attribute from a module located in a package.
#      11
#      12 This utility function is used in custom __getattr__ methods within __init__.py
#    (...)     26     The imported attribute.
#      27 """
#      28 if module_name == "__module__" or module_name is None:
# ---> 29     try:
#      30         result = import_module(f".{attr_name}", package=package)
#      31     except ModuleNotFoundError:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/importlib/__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_core/output_parsers/json.py:17
#      15 from langchain_core.exceptions import OutputParserException
#      16 from langchain_core.output_parsers.format_instructions import JSON_FORMAT_INSTRUCTIONS
# ---> 17 from langchain_core.output_parsers.transform import BaseCumulativeTransformOutputParser
#      18 from langchain_core.outputs import Generation
#      19 from langchain_core.utils.json import (
#      20     parse_and_check_json_markdown,
#      21     parse_json_markdown,
#      22     parse_partial_json,
#      23 )
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_core/output_parsers/transform.py:15
#      12 from typing_extensions import override
#      14 from langchain_core.messages import BaseMessage, BaseMessageChunk
# ---> 15 from langchain_core.output_parsers.base import BaseOutputParser, T
#      16 from langchain_core.outputs import (
#      17     ChatGeneration,
#      18     ChatGenerationChunk,
#      19     Generation,
#      20     GenerationChunk,
#      21 )
#      22 from langchain_core.runnables.config import run_in_executor
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/langchain_core/output_parsers/base.py:65
#      51         """Async parse a list of candidate model Generations into a specific format.
#      52
#      53         Args:
#    (...)     60             Structured output.
#      61         """
#      62         return await run_in_executor(None, self.parse_result, result, partial=partial)
# ---> 65 class BaseGenerationOutputParser(
#      66     BaseLLMOutputParser, RunnableSerializable[LanguageModelOutput, T]
#      67 ):
#      68     """Base class to parse the output of an LLM call."""
#      70     @property
#      71     @override
#      72     def InputType(self) -> Any:
#
# File ~/Documents/sweta/sweta-ai-labs/.venv/lib/python3.14/site-packages/pydantic/_internal/_model_construction.py:156, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     153 namespace['__class_vars__'] = class_vars
#     154 namespace['__private_attributes__'] = {**base_private_attributes, **private_attributes}
# --> 156 cls = cast('type[BaseModel]', super().__new__(mcs, cls_name, bases, namespace, **kwargs))
#     157 BaseModel_ = import_cached_base_model()
#     159 mro = cls.__mro__
#
# File <frozen abc>:106, in ABCMeta.__new__(mcls, name, bases, namespace, **kwargs)
#     105 def __new__(mcls, name, bases, namespace, /, **kwargs):
# --> 106     cls = super().__new__(mcls, name, bases, namespace, **kwargs)
#     107     _abc_init(cls)
#     108     return cls
#
# TypeError: Cannot create a consistent method resolution order (MRO) for bases ABC, Generic

# %%
print("Retrieval Evaluation Results:")
results.to_pandas()
